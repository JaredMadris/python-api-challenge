# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?appid="

# Create dataframe to be added to in for loop
weatherDF = pd.DataFrame()
weatherDF["City"] = ""
weatherDF["Cloudiness"] = ""
weatherDF["Country"] = ""
weatherDF["Date"] = ""
weatherDF["Humidity"] = ""
weatherDF["Lat"] = ""
weatherDF["Lng"] = ""
weatherDF["Max Temp"] = ""
weatherDF["Wind Speed"] = ""

# Print out the beginning of the retrieval notificaiton
print("Beginning Data Retrieval")
print("-------------------------------")

# Loop through all of the cities within the cities array
for x in np.arange(len(cities)):
    
    # Print processing of the current record along with city
    print(f"Processing record {x} | {cities[x]}")

    # Try these things
    try:
        
        # Request the current wheather statistics from built URL of the current city in JSON form
        currentWeather = requests.get(f"{base_url}{api_key}&q={cities[x]}&units=imperial").json()

        # Place all of the variables into the created dataframe
        weatherDF.loc[x, "City"] = currentWeather["name"]
        weatherDF.loc[x, "Cloudiness"] = currentWeather["clouds"]["all"]
        weatherDF.loc[x, "Country"] = currentWeather["sys"]["country"]
        weatherDF.loc[x, "Date"] = currentWeather["dt"]
        weatherDF.loc[x, "Humidity"] = currentWeather["main"]["humidity"]
        weatherDF.loc[x, "Lat"] = currentWeather["coord"]["lat"]
        weatherDF.loc[x, "Lng"] = currentWeather["coord"]["lon"]
        weatherDF.loc[x, "Max Temp"] = currentWeather["main"]["temp_max"]
        weatherDF.loc[x, "Wind Speed"] = currentWeather["wind"]["speed"]

    # If previous block did not work display error message
    except (KeyError, IndexError):
        print("City not found. Skipping...")
        
# Print end of data retrieval process message
print("-------------------------------")
print("Data Retrieval Complete")
print("-------------------------------")
# Drop the rows that have been added with no data or partial data
cleanWeather = weatherDF.dropna()
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing record 0 | qaanaaq
# Processing record 1 | cubarral
# City not found. Skipping...
# Processing record 2 | burnie
# Processing record 3 | castro
# Processing record 4 | busselton
# Processing record 5 | daru
# Processing record 6 | albany
# Processing record 7 | jamestown
# Processing record 8 | yellowknife
# Processing record 9 | brasileia
# City not found. Skipping...
# Processing record 10 | noumea
# Processing record 11 | grand gaube
# Processing record 12 | gerash
# Processing record 13 | bethel
# Processing record 14 | pisco
# Processing record 15 | kavieng
# Processing record 16 | cape town
# Processing record 17 | punta arenas
# Processing record 18 | iqaluit
# Processing record 19 | bathsheba
# Processing record 20 | atuona
# Processing record 21 | yulara
# Processing record 22 | bluff
# Processing record 23 | alofi
# Processing record 24 | galle
# Processing record 25 | lebu
# Processing record 26 | puerto ayora
# Processing record 27 | hithadhoo
# Processing record 28 | mataura
# Processing record 29 | maumere
# Processing record 30 | cockburn harbour
# City not found. Skipping...
# Processing record 31 | hede
# Processing record 32 | rikitea
# Processing record 33 | mandalgovi
# Processing record 34 | tres lagoas
# City not found. Skipping...
# Processing record 35 | ilulissat
# Processing record 36 | chokurdakh
# Processing record 37 | buala
# Processing record 38 | kapaa
# Processing record 39 | faya
# Processing record 40 | barrow
# Processing record 41 | san pedro de macoris
# Processing record 42 | axim
# Processing record 43 | alta floresta
# Processing record 44 | geelong
# Processing record 45 | luebo
# Processing record 46 | chachapoyas
# Processing record 47 | taolanaro
# City not found. Skipping...
# Processing record 48 | zachagansk
# City not found. Skipping...
# Processing record 49 | thompson
# Processing record 50 | salalah
# Processing record 51 | jalcocotan
# Processing record 52 | ushuaia
# Processing record 53 | tabou
# Processing record 54 | ribeira grande
# Processing record 55 | kaitangata
# Processing record 56 | port alfred
# Processing record 57 | paamiut
# Processing record 58 | vestmannaeyjar
# Processing record 59 | tasiilaq
# Processing record 60 | kaoma
# Processing record 61 | twin falls
# Processing record 62 | souillac
# Processing record 63 | butaritari
# Processing record 64 | coari
# Processing record 65 | ramhormoz
# Processing record 66 | belushya guba
# City not found. Skipping...
# Processing record 67 | nome
# Processing record 68 | port hardy
# Processing record 69 | codajas
# Processing record 70 | sfantu gheorghe
# Processing record 71 | hobart
# Processing record 72 | yen bai
# Processing record 73 | saint-philippe
# Processing record 74 | new iberia
# Processing record 75 | dunkwa
# Processing record 76 | sussex
# Processing record 77 | linchuan
# City not found. Skipping...
# Processing record 78 | mar del plata
# Processing record 79 | bambous virieux
# Processing record 80 | humboldt
# Processing record 81 | najran
# Processing record 82 | camacha
# Processing record 83 | norman wells
# Processing record 84 | yerbogachen
# Processing record 85 | ondorhaan
# City not found. Skipping...
# Processing record 86 | herat
# Processing record 87 | nishihara
# Processing record 88 | comodoro rivadavia
# Processing record 89 | abu samrah
# Processing record 90 | verkhnevilyuysk
# Processing record 91 | bredasdorp
# Processing record 92 | palabuhanratu
# City not found. Skipping...
# Processing record 93 | arraial do cabo
# Processing record 94 | menongue
# Processing record 95 | bayir
# Processing record 96 | saldanha
# Processing record 97 | jerantut
# Processing record 98 | georgetown
# Processing record 99 | ancud
# Processing record 100 | voyvozh
# Processing record 101 | vaini
# Processing record 102 | shishou
# Processing record 103 | hermanus
# Processing record 104 | geraldton
# Processing record 105 | kodiak
# Processing record 106 | tura
# Processing record 107 | loralai
# Processing record 108 | torbay
# Processing record 109 | tongsa
# City not found. Skipping...
# Processing record 110 | meulaboh
# Processing record 111 | sinop
# Processing record 112 | upernavik
# Processing record 113 | sinkat
# City not found. Skipping...
# Processing record 114 | maragogi
# Processing record 115 | aksu
# Processing record 116 | tiksi
# Processing record 117 | praia
# Processing record 118 | san patricio
# Processing record 119 | keti bandar
# Processing record 120 | porto novo
# Processing record 121 | lata
# Processing record 122 | esperance
# Processing record 123 | port elizabeth
# Processing record 124 | avarua
# Processing record 125 | atasu
# Processing record 126 | kuusamo
# Processing record 127 | sainte-maxime
# Processing record 128 | pacific grove
# Processing record 129 | puerto el triunfo
# Processing record 130 | mys shmidta
# City not found. Skipping...
# Processing record 131 | muros
# Processing record 132 | dianopolis
# City not found. Skipping...
# Processing record 133 | kudahuvadhoo
# Processing record 134 | luderitz
# Processing record 135 | vuktyl
# Processing record 136 | saleaula
# City not found. Skipping...
# Processing record 137 | saskylakh
# Processing record 138 | yomitan
# City not found. Skipping...
# Processing record 139 | havre-saint-pierre
# Processing record 140 | tuktoyaktuk
# Processing record 141 | gimli
# Processing record 142 | udachnyy
# Processing record 143 | deputatskiy
# Processing record 144 | san jose
# Processing record 145 | lahaina
# Processing record 146 | ust-kamchatsk
# City not found. Skipping...
# Processing record 147 | bengkulu
# City not found. Skipping...
# Processing record 148 | klimovo
# Processing record 149 | zhezkazgan
# Processing record 150 | porto belo
# Processing record 151 | petropavlovsk-kamchatskiy
# Processing record 152 | lorengau
# Processing record 153 | natal
# Processing record 154 | saint-augustin
# Processing record 155 | asau
# City not found. Skipping...
# Processing record 156 | ranong
# Processing record 157 | aklavik
# Processing record 158 | tasbuget
# City not found. Skipping...
# Processing record 159 | northam
# Processing record 160 | harlau
# Processing record 161 | santa luzia
# Processing record 162 | aleppo
# Processing record 163 | clyde river
# Processing record 164 | naze
# Processing record 165 | hastings
# Processing record 166 | guarapari
# Processing record 167 | hovd
# Processing record 168 | kamenka
# Processing record 169 | talaya
# Processing record 170 | richards bay
# Processing record 171 | tumannyy
# City not found. Skipping...
# Processing record 172 | komsomolskiy
# Processing record 173 | aranos
# Processing record 174 | diffa
# Processing record 175 | mount darwin
# Processing record 176 | malwan
# City not found. Skipping...
# Processing record 177 | tabiauea
# City not found. Skipping...
# Processing record 178 | zyryanka
# Processing record 179 | mount gambier
# Processing record 180 | saint-leu
# Processing record 181 | butembo
# Processing record 182 | chuy
# Processing record 183 | carnarvon
# Processing record 184 | illoqqortoormiut
# City not found. Skipping...
# Processing record 185 | bestobe
# Processing record 186 | nikolskoye
# Processing record 187 | alihe
# Processing record 188 | senanga
# Processing record 189 | mahebourg
# Processing record 190 | sur
# Processing record 191 | lusambo
# Processing record 192 | hofn
# Processing record 193 | lolua
# City not found. Skipping...
# Processing record 194 | los llanos de aridane
# Processing record 195 | masaka
# Processing record 196 | cherskiy
# Processing record 197 | kijang
# Processing record 198 | anadyr
# Processing record 199 | saint george
# Processing record 200 | coihaique
# Processing record 201 | malinovoye ozero
# Processing record 202 | fortuna
# Processing record 203 | derzhavinsk
# Processing record 204 | nanyamba
# Processing record 205 | saginaw
# Processing record 206 | severo-kurilsk
# Processing record 207 | faanui
# Processing record 208 | tsihombe
# City not found. Skipping...
# Processing record 209 | fairbanks
# Processing record 210 | dawei
# Processing record 211 | tucuman
# Processing record 212 | provideniya
# Processing record 213 | dudinka
# Processing record 214 | umm lajj
# Processing record 215 | padang
# Processing record 216 | iquitos
# Processing record 217 | lavrentiya
# Processing record 218 | narsaq
# Processing record 219 | lamu
# Processing record 220 | hilo
# Processing record 221 | zaozerne
# Processing record 222 | katsuura
# Processing record 223 | bintulu
# Processing record 224 | shibetsu
# Processing record 225 | temaraia
# City not found. Skipping...
# Processing record 226 | dawson creek
# Processing record 227 | east london
# Processing record 228 | ryotsu
# Processing record 229 | vao
# Processing record 230 | pomabamba
# Processing record 231 | new norfolk
# Processing record 232 | xadani
# City not found. Skipping...
# Processing record 233 | rafai
# Processing record 234 | yamnytsya
# Processing record 235 | hualmay
# Processing record 236 | kayes
# Processing record 237 | lincoln
# Processing record 238 | bandarbeyla
# Processing record 239 | saeby
# Processing record 240 | krasnoselkup
# City not found. Skipping...
# Processing record 241 | tungkang
# City not found. Skipping...
# Processing record 242 | usakos
# Processing record 243 | tawkar
# City not found. Skipping...
# Processing record 244 | farah
# Processing record 245 | zabol
# Processing record 246 | ashtian
# Processing record 247 | san lorenzo
# Processing record 248 | onguday
# Processing record 249 | jiaonan
# Processing record 250 | nelson bay
# Processing record 251 | kella
# Processing record 252 | jizan
# Processing record 253 | barentsburg
# City not found. Skipping...
# Processing record 254 | raudeberg
# Processing record 255 | sabang
# Processing record 256 | newton
# Processing record 257 | nizhneyansk
# City not found. Skipping...
# Processing record 258 | ngukurr
# City not found. Skipping...
# Processing record 259 | pala
# Processing record 260 | saint-pierre
# Processing record 261 | shimoda
# Processing record 262 | moiyabana
# City not found. Skipping...
# Processing record 263 | saint-georges
# Processing record 264 | codrington
# Processing record 265 | dikson
# Processing record 266 | kamenskoye
# City not found. Skipping...
# Processing record 267 | vannes
# Processing record 268 | laguna
# Processing record 269 | beringovskiy
# Processing record 270 | tombouctou
# Processing record 271 | atar
# Processing record 272 | jalu
# Processing record 273 | tsiroanomandidy
# Processing record 274 | touros
# Processing record 275 | zhenlai
# Processing record 276 | inhambane
# Processing record 277 | kiruna
# Processing record 278 | george town
# Processing record 279 | kyra
# City not found. Skipping...
# Processing record 280 | zhigansk
# Processing record 281 | kruisfontein
# Processing record 282 | bhanpuri
# Processing record 283 | saverne
# Processing record 284 | half moon bay
# Processing record 285 | ribeira brava
# Processing record 286 | darnah
# Processing record 287 | san cristobal
# Processing record 288 | mandeville
# Processing record 289 | port-gentil
# Processing record 290 | vonnu
# City not found. Skipping...
# Processing record 291 | sydney
# Processing record 292 | krasnyy oktyabr
# Processing record 293 | tecoanapa
# Processing record 294 | santo antonio do ica
# Processing record 295 | portland
# Processing record 296 | margate
# Processing record 297 | bolgatanga
# Processing record 298 | labutta
# City not found. Skipping...
# Processing record 299 | siguiri
# Processing record 300 | doctor pedro p. pena
# City not found. Skipping...
# Processing record 301 | hasaki
# Processing record 302 | jucas
# Processing record 303 | nova olimpia
# Processing record 304 | del monte
# Processing record 305 | dolores
# Processing record 306 | lasa
# Processing record 307 | lompoc
# Processing record 308 | vila franca do campo
# Processing record 309 | ucluelet
# Processing record 310 | ostrovnoy
# Processing record 311 | necochea
# Processing record 312 | mala
# Processing record 313 | lundazi
# Processing record 314 | kahului
# Processing record 315 | cervo
# Processing record 316 | nanortalik
# Processing record 317 | bolshaya yelkhovka
# City not found. Skipping...
# Processing record 318 | beloye
# Processing record 319 | samut songkhram
# Processing record 320 | evensk
# Processing record 321 | cambridge
# Processing record 322 | fukue
# Processing record 323 | pevek
# Processing record 324 | linshu
# City not found. Skipping...
# Processing record 325 | muret
# Processing record 326 | simao
# Processing record 327 | roebourne
# Processing record 328 | tommot
# Processing record 329 | rocha
# Processing record 330 | sentyabrskiy
# City not found. Skipping...
# Processing record 331 | aripuana
# Processing record 332 | zambezi
# Processing record 333 | berlevag
# Processing record 334 | washougal
# Processing record 335 | victoria
# Processing record 336 | haicheng
# Processing record 337 | pokosnoye
# Processing record 338 | cidreira
# Processing record 339 | okha
# Processing record 340 | umm bab
# Processing record 341 | tutoia
# Processing record 342 | maldonado
# Processing record 343 | sibolga
# Processing record 344 | kalabo
# Processing record 345 | kamina
# Processing record 346 | touba
# Processing record 347 | sioux lookout
# Processing record 348 | constitucion
# Processing record 349 | aranyosapati
# Processing record 350 | acapulco
# Processing record 351 | zverinogolovskoye
# Processing record 352 | taraclia
# Processing record 353 | romanovo
# Processing record 354 | klaksvik
# Processing record 355 | peniche
# Processing record 356 | erzin
# Processing record 357 | cairns
# Processing record 358 | vinh
# Processing record 359 | namibe
# Processing record 360 | morrope
# Processing record 361 | dunedin
# Processing record 362 | kommunisticheskiy
# Processing record 363 | puerto madero
# Processing record 364 | jiazi
# Processing record 365 | nouakchott
# Processing record 366 | antalaha
# Processing record 367 | mocuba
# Processing record 368 | mersing
# Processing record 369 | senj
# Processing record 370 | eyl
# Processing record 371 | tabuk
# Processing record 372 | yorkton
# Processing record 373 | ayios kirikos
# City not found. Skipping...
# Processing record 374 | jiexiu
# Processing record 375 | shchelyayur
# City not found. Skipping...
# Processing record 376 | olafsvik
# City not found. Skipping...
# Processing record 377 | ilebo
# Processing record 378 | ballina
# Processing record 379 | esil
# Processing record 380 | oktyabrskiy
# Processing record 381 | kaeo
# Processing record 382 | grand river south east
# City not found. Skipping...
# Processing record 383 | aflu
# City not found. Skipping...
# Processing record 384 | nouadhibou
# Processing record 385 | pierre
# Processing record 386 | choconta
# Processing record 387 | general roca
# Processing record 388 | slave lake
# Processing record 389 | juneau
# Processing record 390 | zhuhai
# Processing record 391 | greenville
# Processing record 392 | cayenne
# Processing record 393 | kenai
# Processing record 394 | victor harbor
# Processing record 395 | lethem
# Processing record 396 | ponta do sol
# Processing record 397 | talnakh
# Processing record 398 | ahipara
# Processing record 399 | marshall
# Processing record 400 | satitoa
# City not found. Skipping...
# Processing record 401 | chunhuhub
# Processing record 402 | la seyne-sur-mer
# Processing record 403 | amderma
# City not found. Skipping...
# Processing record 404 | oksovskiy
# Processing record 405 | shenjiamen
# Processing record 406 | ulaanbaatar
# Processing record 407 | sisimiut
# Processing record 408 | chapais
# Processing record 409 | kousseri
# City not found. Skipping...
# Processing record 410 | taltal
# Processing record 411 | rungata
# City not found. Skipping...
# Processing record 412 | itarema
# Processing record 413 | kattivakkam
# Processing record 414 | longyearbyen
# Processing record 415 | huajuapan
# City not found. Skipping...
# Processing record 416 | pochutla
# Processing record 417 | sroda wielkopolska
# Processing record 418 | yar-sale
# Processing record 419 | cabo san lucas
# Processing record 420 | ibra
# Processing record 421 | pangody
# Processing record 422 | cap malheureux
# Processing record 423 | roma
# Processing record 424 | chute-aux-outardes
# Processing record 425 | saint anthony
# Processing record 426 | san carlos de bariloche
# Processing record 427 | pangai
# Processing record 428 | baykit
# Processing record 429 | semirom
# Processing record 430 | mancio lima
# City not found. Skipping...
# Processing record 431 | barcelos
# Processing record 432 | ixtapa
# Processing record 433 | port macquarie
# Processing record 434 | mecca
# Processing record 435 | wakkanai
# Processing record 436 | halalo
# City not found. Skipping...
# Processing record 437 | dawlatabad
# Processing record 438 | hurghada
# City not found. Skipping...
# Processing record 439 | luwuk
# Processing record 440 | isangel
# Processing record 441 | le port
# Processing record 442 | papara
# Processing record 443 | barra patuca
# Processing record 444 | mumford
# Processing record 445 | shepsi
# Processing record 446 | nyimba
# Processing record 447 | springbok
# Processing record 448 | glen allen
# Processing record 449 | hervey bay
# Processing record 450 | lakhdenpokhya
# Processing record 451 | beaverlodge
# Processing record 452 | araouane
# Processing record 453 | vanavara
# Processing record 454 | mantua
# Processing record 455 | guerrero negro
# Processing record 456 | macas
# Processing record 457 | sobolevo
# Processing record 458 | umea
# Processing record 459 | digapahandi
# Processing record 460 | vaitupu
# City not found. Skipping...
# Processing record 461 | pavilosta
# Processing record 462 | romny
# Processing record 463 | athens
# Processing record 464 | maniitsoq
# Processing record 465 | palmer
# Processing record 466 | fengzhen
# Processing record 467 | altamira
# Processing record 468 | umm kaddadah
# Processing record 469 | machico
# Processing record 470 | tazovskiy
# Processing record 471 | bud
# Processing record 472 | akaltara
# Processing record 473 | te anau
# Processing record 474 | xining
# Processing record 475 | batagay-alyta
# Processing record 476 | airai
# Processing record 477 | belaya gora
# Processing record 478 | yarada
# Processing record 479 | crateus
# Processing record 480 | vila velha
# Processing record 481 | santa isabel
# Processing record 482 | paraiso
# Processing record 483 | kazachinskoye
# Processing record 484 | murgab
# Processing record 485 | dombarovskiy
# Processing record 486 | mossendjo
# Processing record 487 | okhotsk
# Processing record 488 | umzimvubu
# City not found. Skipping...
# Processing record 489 | bonavista
# Processing record 490 | lagoa
# Processing record 491 | jinja
# Processing record 492 | casambalangan
# Processing record 493 | braslav
# City not found. Skipping...
# Processing record 494 | kalmunai
# Processing record 495 | attawapiskat
# City not found. Skipping...
# Processing record 496 | sinnamary
# Processing record 497 | atherton
# Processing record 498 | labuhan
# Processing record 499 | amelia
# Processing record 500 | hambantota
# Processing record 501 | karakendzha
# City not found. Skipping...
# Processing record 502 | cockburn town
# Processing record 503 | ugoofaaru
# Processing record 504 | the valley
# Processing record 505 | dingzhou
# Processing record 506 | arauca
# Processing record 507 | haapiti
# Processing record 508 | la ronge
# Processing record 509 | gazanjyk
# Processing record 510 | saint-joseph
# Processing record 511 | lardos
# Processing record 512 | curup
# Processing record 513 | chicama
# Processing record 514 | corinto
# Processing record 515 | filadelfia
# Processing record 516 | mananjary
# Processing record 517 | rio muerto
# Processing record 518 | luang prabang
# Processing record 519 | katangli
# Processing record 520 | conceicao do araguaia
# Processing record 521 | egvekinot
# Processing record 522 | pafos
# City not found. Skipping...
# Processing record 523 | quesnel
# Processing record 524 | ginda
# Processing record 525 | revda
# Processing record 526 | artyk
# City not found. Skipping...
# Processing record 527 | vestmanna
# Processing record 528 | armstrong
# Processing record 529 | gondanglegi
# Processing record 530 | pauini
# Processing record 531 | karratha
# Processing record 532 | lukavica
# Processing record 533 | qaqortoq
# Processing record 534 | isla mujeres
# Processing record 535 | leningradskiy
# Processing record 536 | kulunda
# Processing record 537 | teodoro sampaio
# Processing record 538 | tuatapere
# Processing record 539 | mount isa
# Processing record 540 | makakilo city
# Processing record 541 | sitka
# Processing record 542 | kapit
# Processing record 543 | vila do maio
# Processing record 544 | dickinson
# Processing record 545 | leshukonskoye
# Processing record 546 | kuche
# City not found. Skipping...
# Processing record 547 | college
# Processing record 548 | yuncheng
# Processing record 549 | qandala
# Processing record 550 | khatanga
# Processing record 551 | carlisle
# Processing record 552 | nidadavole
# Processing record 553 | orthez
# Processing record 554 | shingu
# Processing record 555 | vavozh
# Processing record 556 | port keats
# Processing record 557 | riyadh
# Processing record 558 | santa isabel do rio negro
# Processing record 559 | nautla
# Processing record 560 | magan
# Processing record 561 | bandar-e torkaman
# City not found. Skipping...
# Processing record 562 | ippy
# Processing record 563 | galiwinku
# City not found. Skipping...
# Processing record 564 | nova olinda do norte
# Processing record 565 | belmonte
# Processing record 566 | kununurra
# Processing record 567 | puri
# Processing record 568 | urucuca
# Processing record 569 | tidore
# City not found. Skipping...
# Processing record 570 | aswan
# Processing record 571 | awjilah
# Processing record 572 | leopold
# Processing record 573 | huilong
# Processing record 574 | meiganga
# Processing record 575 | dok kham tai
# Processing record 576 | ati
# Processing record 577 | key west
# Processing record 578 | akureyri
# Processing record 579 | kasangulu
# Processing record 580 | ambilobe
# Processing record 581 | ahuimanu
# Processing record 582 | westport
# Processing record 583 | prince rupert
# Processing record 584 | inirida
# Processing record 585 | miles city
# Processing record 586 | san quintin
# Processing record 587 | aitape
# Processing record 588 | olinda
# Processing record 589 | baglan
# Processing record 590 | listvyagi
# Processing record 591 | benito juarez
# Processing record 592 | itea
# Processing record 593 | fremont
# Processing record 594 | thiruvananthapuram
# Processing record 595 | juegang
# Processing record 596 | hof
# Processing record 597 | adrar
# Processing record 598 | normandin
# Processing record 599 | duz
# City not found. Skipping...
# Processing record 600 | bogande
# Processing record 601 | sao filipe
# Processing record 602 | kurchum
# Processing record 603 | bilibino
# Processing record 604 | marcona
# City not found. Skipping...
# Processing record 605 | chimore
# Processing record 606 | ygatimi
# Processing record 607 | tukrah
# City not found. Skipping...
# Processing record 608 | miramar
# Processing record 609 | port lincoln
# Processing record 610 | manhattan
# Processing record 611 | buraydah
# Processing record 612 | samusu
# City not found. Skipping...
# Processing record 613 | malko tarnovo
# Processing record 614 | beisfjord
# Processing record 615 | kendari
# Processing record 616 | pestretsy
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cleanWeather.to_csv(output_data_file)
# Display counts of each column
cleanWeather.count()
# Out:
# City          546
# Cloudiness    546
# Country       546
# Date          546
# Humidity      546
# Lat           546
# Lng           546
# Max Temp      546
# Wind Speed    546
# dtype: int64

# %%
#Display the final dataframe
cleanWeather.head()
# Out:
#         City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0    Qaanaaq        100      GL  1575143426       93  77.48  -69.36     9.84
# 2     Burnie        100      AU  1575143426       79 -41.05  145.91    48.99
# 3     Castro         75      CL  1575143426       76 -42.48  -73.76     55.4
# 4  Busselton          0      AU  1575143173       45 -33.64  115.35       55
# 5       Daru         97      PG  1575143426       87  -9.07  143.21    78.33
#
#   Wind Speed
# 0       9.35
# 2       1.99
# 3       6.93
# 4      12.46
# 5       4.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plot a scatter plot of latitude vs temperature with formatting
plt.scatter(cleanWeather["Lat"], cleanWeather["Max Temp"], color="cadetblue",
edgecolors = "k", s = 50)

# Plot title and axis labels as well as the grid
plt.title(f"City Latitude vs. Max Temperature (11/29/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# Save the figure to the output folder
plt.savefig("output_data/latVtemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plot a scatter plot of latitude vs humidity with formatting
plt.scatter(cleanWeather["Lat"], cleanWeather["Humidity"],color="cadetblue",
edgecolors = "k", s = 50)

# Plot title and axis labels as well as the grid
plt.title("City Latitude vs. Humidity (11/03/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure to the output folder
plt.savefig("output_data/latVhum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plot a scatter plot of latitude vs cloudiness with formatting
plt.scatter(cleanWeather["Lat"], cleanWeather["Cloudiness"],color="cadetblue",
edgecolors = "k", s = 50)

# Plot title and axis labels as well as the grid
plt.title("City Latitude vs. Cloudiness (11/03/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure to the output folder
plt.savefig("output_data/latVcloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plot a scatter plot of latitude vs wind speed with formatting
plt.scatter(cleanWeather["Lat"], cleanWeather["Wind Speed"],color="cadetblue",
edgecolors = "k", s = 50)

# Plot title and axis labels as well as the grid
plt.title("City Latitude vs. Wind Speed (11/03/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

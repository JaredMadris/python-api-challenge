# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?appid="

# Create dataframe for loop
weatherDF = pd.DataFrame()
weatherDF["City"] = ""
weatherDF["Cloudiness"] = ""
weatherDF["Country"] = ""
weatherDF["Date"] = ""
weatherDF["Humidity"] = ""
weatherDF["Lat"] = ""
weatherDF["Lng"] = ""
weatherDF["Max Temp"] = ""
weatherDF["Wind Speed"] = ""

# Print Beginning Data Retrieval
print("Beginning Data Retrieval")
print("-------------------------------")

# Loop through all cities within cities
for x in np.arange(len(cities)):
    
    # Print processing of current record and city
    print(f"Processing record {x} | {cities[x]}")

    # Try these things
    try:
        
        # Request the current weather stats from URL in JSON form
        currentweather = requests.get(f"{base_url}{api_key}&q={cities[x]}&units=imperial").json()

        # Dataframe Variables
        weatherDF.loc[x, "City"] = currentweather["name"]
        weatherDF.loc[x, "Cloudiness"] = currentweather["clouds"]["all"]
        weatherDF.loc[x, "Country"] = currentweather["sys"]["country"]
        weatherDF.loc[x, "Date"] = currentweather["dt"]
        weatherDF.loc[x, "Humidity"] = currentweather["main"]["humidity"]
        weatherDF.loc[x, "Lat"] = currentweather["coord"]["lat"]
        weatherDF.loc[x, "Lng"] = currentweather["coord"]["lon"]
        weatherDF.loc[x, "Max Temp"] = currentweather["main"]["temp_max"]
        weatherDF.loc[x, "Wind Speed"] = currentweather["wind"]["speed"]

    # If previous block did not work display error message
    except (KeyError, IndexError):
        print("City not found. Skipping...")
        
# Print Data Retrieval Complete
print("-------------------------------")
print("Data Retrieval Complete")
print("-------------------------------")

# Drop rows that have been added with no data or partial data
goodweather = weatherDF.dropna()
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing record 0 | mount isa
# Processing record 1 | namatanai
# Processing record 2 | cherskiy
# Processing record 3 | mataura
# Processing record 4 | hermanus
# Processing record 5 | yerbogachen
# Processing record 6 | cidreira
# Processing record 7 | kahului
# Processing record 8 | albany
# Processing record 9 | acapulco
# Processing record 10 | taolanaro
# City not found. Skipping...
# Processing record 11 | hithadhoo
# Processing record 12 | castro
# Processing record 13 | rikitea
# Processing record 14 | cockburn town
# Processing record 15 | belmonte
# Processing record 16 | barentsburg
# City not found. Skipping...
# Processing record 17 | lavrentiya
# Processing record 18 | ixtapa
# Processing record 19 | pyinmana
# Processing record 20 | busselton
# Processing record 21 | louisbourg
# City not found. Skipping...
# Processing record 22 | kajaani
# Processing record 23 | yialos
# City not found. Skipping...
# Processing record 24 | malakal
# City not found. Skipping...
# Processing record 25 | xiongzhou
# Processing record 26 | makakilo city
# Processing record 27 | coihaique
# Processing record 28 | punta arenas
# Processing record 29 | ilulissat
# Processing record 30 | puerto ayora
# Processing record 31 | port alfred
# Processing record 32 | kapaa
# Processing record 33 | haibowan
# City not found. Skipping...
# Processing record 34 | carnarvon
# Processing record 35 | saint anthony
# Processing record 36 | san julian
# Processing record 37 | moba
# Processing record 38 | severo-kurilsk
# Processing record 39 | issia
# Processing record 40 | dingle
# Processing record 41 | vardo
# Processing record 42 | mar del plata
# Processing record 43 | airai
# Processing record 44 | tucume
# Processing record 45 | vestmannaeyjar
# Processing record 46 | bambous virieux
# Processing record 47 | port elizabeth
# Processing record 48 | komsomolskiy
# Processing record 49 | lebu
# Processing record 50 | atuona
# Processing record 51 | hobart
# Processing record 52 | coquimbo
# Processing record 53 | ushuaia
# Processing record 54 | nikolskoye
# Processing record 55 | khatanga
# Processing record 56 | mount gambier
# Processing record 57 | vaini
# Processing record 58 | borgarnes
# Processing record 59 | sayyan
# Processing record 60 | tiksi
# Processing record 61 | dingzhou
# Processing record 62 | poso
# Processing record 63 | albemarle
# Processing record 64 | iranshahr
# Processing record 65 | amderma
# City not found. Skipping...
# Processing record 66 | batemans bay
# Processing record 67 | marawi
# Processing record 68 | georgetown
# Processing record 69 | abha
# Processing record 70 | grand river south east
# City not found. Skipping...
# Processing record 71 | saint paul
# Processing record 72 | taltal
# Processing record 73 | pavilosta
# Processing record 74 | nizhneyansk
# City not found. Skipping...
# Processing record 75 | kavieng
# Processing record 76 | bilibino
# Processing record 77 | gallup
# Processing record 78 | avarua
# Processing record 79 | francisco sa
# Processing record 80 | bay roberts
# Processing record 81 | klaksvik
# Processing record 82 | ulladulla
# Processing record 83 | el alto
# Processing record 84 | trinidad
# Processing record 85 | haines junction
# Processing record 86 | cape town
# Processing record 87 | kodiak
# Processing record 88 | diego de almagro
# Processing record 89 | margate
# Processing record 90 | san cristobal
# Processing record 91 | kiama
# Processing record 92 | kidal
# Processing record 93 | samalaeulu
# City not found. Skipping...
# Processing record 94 | kuva
# City not found. Skipping...
# Processing record 95 | aksu
# Processing record 96 | nichinan
# Processing record 97 | bombay
# Processing record 98 | puerto escondido
# Processing record 99 | tsarychanka
# Processing record 100 | srednekolymsk
# Processing record 101 | barrow
# Processing record 102 | grand gaube
# Processing record 103 | tasiilaq
# Processing record 104 | salalah
# Processing record 105 | pangnirtung
# Processing record 106 | venafro
# Processing record 107 | saldanha
# Processing record 108 | khorixas
# Processing record 109 | kenai
# Processing record 110 | magnolia
# Processing record 111 | bluff
# Processing record 112 | illoqqortoormiut
# City not found. Skipping...
# Processing record 113 | kartaly
# Processing record 114 | pacific grove
# Processing record 115 | avera
# Processing record 116 | barcelos
# Processing record 117 | matara
# Processing record 118 | esperance
# Processing record 119 | faanui
# Processing record 120 | bredasdorp
# Processing record 121 | lindi
# Processing record 122 | gayny
# Processing record 123 | yarim
# Processing record 124 | salinas
# Processing record 125 | kyabram
# Processing record 126 | kalmunai
# Processing record 127 | bargal
# City not found. Skipping...
# Processing record 128 | fernandez
# Processing record 129 | hambantota
# Processing record 130 | floro
# Processing record 131 | jamestown
# Processing record 132 | salvador
# Processing record 133 | dikson
# Processing record 134 | kaitangata
# Processing record 135 | hualmay
# Processing record 136 | matay
# Processing record 137 | pisco
# Processing record 138 | kangaatsiaq
# Processing record 139 | port lincoln
# Processing record 140 | kondoros
# Processing record 141 | huilong
# Processing record 142 | chokurdakh
# Processing record 143 | nanortalik
# Processing record 144 | cienfuegos
# Processing record 145 | prince rupert
# Processing record 146 | sangmelima
# Processing record 147 | saint-philippe
# Processing record 148 | hilo
# Processing record 149 | kavaratti
# Processing record 150 | saskylakh
# Processing record 151 | rosarito
# Processing record 152 | ancud
# Processing record 153 | koumac
# Processing record 154 | egvekinot
# Processing record 155 | prince albert
# Processing record 156 | talnakh
# Processing record 157 | zhezkazgan
# Processing record 158 | novikovo
# Processing record 159 | lerwick
# Processing record 160 | dresden
# Processing record 161 | tuktoyaktuk
# Processing record 162 | mao
# Processing record 163 | piacabucu
# Processing record 164 | luba
# Processing record 165 | yumen
# Processing record 166 | ribeira grande
# Processing record 167 | bonthe
# Processing record 168 | victoria
# Processing record 169 | luderitz
# Processing record 170 | samusu
# City not found. Skipping...
# Processing record 171 | rongcheng
# Processing record 172 | millet
# Processing record 173 | oudtshoorn
# Processing record 174 | fort-shevchenko
# Processing record 175 | isangel
# Processing record 176 | lobito
# Processing record 177 | guelph
# Processing record 178 | mys shmidta
# City not found. Skipping...
# Processing record 179 | halle
# Processing record 180 | manbij
# Processing record 181 | fairbanks
# Processing record 182 | telfs
# Processing record 183 | qaanaaq
# Processing record 184 | belushya guba
# City not found. Skipping...
# Processing record 185 | alta floresta
# Processing record 186 | urucui
# Processing record 187 | clyde river
# Processing record 188 | kamenskoye
# City not found. Skipping...
# Processing record 189 | mahebourg
# Processing record 190 | krasnovishersk
# Processing record 191 | griffith
# Processing record 192 | norman wells
# Processing record 193 | chinsali
# Processing record 194 | mezen
# Processing record 195 | longyearbyen
# Processing record 196 | skowhegan
# Processing record 197 | provideniya
# Processing record 198 | tabou
# Processing record 199 | boende
# Processing record 200 | calderitas
# Processing record 201 | nefteyugansk
# Processing record 202 | hirara
# Processing record 203 | nome
# Processing record 204 | muisne
# Processing record 205 | tucuman
# Processing record 206 | geraldton
# Processing record 207 | clinton
# Processing record 208 | toccoa
# Processing record 209 | upernavik
# Processing record 210 | butaritari
# Processing record 211 | mayumba
# Processing record 212 | vilyuysk
# Processing record 213 | waingapu
# Processing record 214 | chicama
# Processing record 215 | mashhad
# Processing record 216 | rungata
# City not found. Skipping...
# Processing record 217 | yellowknife
# Processing record 218 | chuy
# Processing record 219 | tazovskiy
# Processing record 220 | tucano
# Processing record 221 | sitka
# Processing record 222 | constitucion
# Processing record 223 | alofi
# Processing record 224 | shimoda
# Processing record 225 | omsukchan
# Processing record 226 | russell
# Processing record 227 | husavik
# Processing record 228 | lagoa
# Processing record 229 | oktyabrskoye
# Processing record 230 | uyemskiy
# Processing record 231 | tharad
# Processing record 232 | aberfoyle
# Processing record 233 | tabiauea
# City not found. Skipping...
# Processing record 234 | san policarpo
# Processing record 235 | rudnichnyy
# Processing record 236 | saleaula
# City not found. Skipping...
# Processing record 237 | kashi
# City not found. Skipping...
# Processing record 238 | bolungarvik
# City not found. Skipping...
# Processing record 239 | sao jose da coroa grande
# Processing record 240 | kropotkin
# Processing record 241 | naze
# Processing record 242 | novobirilyussy
# Processing record 243 | guajara-mirim
# City not found. Skipping...
# Processing record 244 | keskin
# Processing record 245 | vestmanna
# Processing record 246 | plettenberg bay
# Processing record 247 | lovozero
# Processing record 248 | kudahuvadhoo
# Processing record 249 | ahipara
# Processing record 250 | cayenne
# Processing record 251 | maues
# Processing record 252 | horta
# Processing record 253 | omboue
# Processing record 254 | mildura
# Processing record 255 | fortuna
# Processing record 256 | bull savanna
# Processing record 257 | sur
# Processing record 258 | ponta do sol
# Processing record 259 | benjamin constant
# Processing record 260 | lompoc
# Processing record 261 | meulaboh
# Processing record 262 | port-gentil
# Processing record 263 | bar harbor
# Processing record 264 | ayolas
# Processing record 265 | aklavik
# Processing record 266 | new norfolk
# Processing record 267 | tuatapere
# Processing record 268 | korla
# City not found. Skipping...
# Processing record 269 | hasaki
# Processing record 270 | san pedro
# Processing record 271 | northam
# Processing record 272 | businga
# Processing record 273 | saint george
# Processing record 274 | northport
# Processing record 275 | walvis bay
# Processing record 276 | gat
# Processing record 277 | balakovo
# Processing record 278 | anloga
# Processing record 279 | leshukonskoye
# Processing record 280 | jacareacanga
# Processing record 281 | palabuhanratu
# City not found. Skipping...
# Processing record 282 | zhigansk
# Processing record 283 | torbay
# Processing record 284 | baykit
# Processing record 285 | corralillo
# Processing record 286 | umzimvubu
# City not found. Skipping...
# Processing record 287 | leninskoye
# Processing record 288 | port macquarie
# Processing record 289 | padang
# Processing record 290 | pangkalanbuun
# Processing record 291 | conde
# Processing record 292 | wukari
# Processing record 293 | east london
# Processing record 294 | beyneu
# Processing record 295 | chabahar
# Processing record 296 | skibbereen
# Processing record 297 | souillac
# Processing record 298 | tommot
# Processing record 299 | mitsamiouli
# Processing record 300 | narsaq
# Processing record 301 | santiago de las vegas
# Processing record 302 | hay river
# Processing record 303 | vanavara
# Processing record 304 | caxias
# Processing record 305 | cabedelo
# Processing record 306 | dehloran
# Processing record 307 | asilah
# City not found. Skipping...
# Processing record 308 | yulara
# Processing record 309 | wulanhaote
# City not found. Skipping...
# Processing record 310 | sao filipe
# Processing record 311 | saint-augustin
# Processing record 312 | mackay
# Processing record 313 | shellbrook
# Processing record 314 | kaeo
# Processing record 315 | pevek
# Processing record 316 | matamoros
# Processing record 317 | natal
# Processing record 318 | nagato
# Processing record 319 | krasnogorskoye
# Processing record 320 | diu
# Processing record 321 | rawson
# Processing record 322 | lazaro cardenas
# Processing record 323 | touros
# Processing record 324 | aden
# Processing record 325 | port hardy
# Processing record 326 | mirnyy
# Processing record 327 | lasa
# Processing record 328 | vaitupu
# City not found. Skipping...
# Processing record 329 | broome
# Processing record 330 | soe
# Processing record 331 | kazerun
# Processing record 332 | redlands
# Processing record 333 | marzuq
# Processing record 334 | cervo
# Processing record 335 | labuhan
# Processing record 336 | tocopilla
# Processing record 337 | wolgast
# Processing record 338 | biltine
# Processing record 339 | nizhniy tsasuchey
# Processing record 340 | pokhara
# Processing record 341 | guerrero negro
# Processing record 342 | kloulklubed
# Processing record 343 | alamosa
# Processing record 344 | bethel
# Processing record 345 | portland
# Processing record 346 | hobyo
# Processing record 347 | hit
# Processing record 348 | vite
# Processing record 349 | mastic beach
# Processing record 350 | navapur
# City not found. Skipping...
# Processing record 351 | goderich
# Processing record 352 | itambacuri
# Processing record 353 | henties bay
# Processing record 354 | querfurt
# Processing record 355 | broken hill
# Processing record 356 | khonuu
# City not found. Skipping...
# Processing record 357 | iqaluit
# Processing record 358 | richards bay
# Processing record 359 | myitkyina
# Processing record 360 | yar-sale
# Processing record 361 | gornopravdinsk
# Processing record 362 | queenstown
# Processing record 363 | birao
# Processing record 364 | talcahuano
# Processing record 365 | kattivakkam
# Processing record 366 | turukhansk
# Processing record 367 | koungou
# City not found. Skipping...
# Processing record 368 | vizinga
# Processing record 369 | maniitsoq
# Processing record 370 | jaque
# City not found. Skipping...
# Processing record 371 | umba
# Processing record 372 | karpathos
# Processing record 373 | palmer
# Processing record 374 | makokou
# Processing record 375 | ola
# Processing record 376 | manchester
# Processing record 377 | vostok
# Processing record 378 | sorland
# Processing record 379 | dawei
# Processing record 380 | ayagoz
# Processing record 381 | pasir gudang
# Processing record 382 | high rock
# Processing record 383 | petropavlovskoye
# Processing record 384 | kawana waters
# City not found. Skipping...
# Processing record 385 | bababe
# City not found. Skipping...
# Processing record 386 | tsihombe
# City not found. Skipping...
# Processing record 387 | dubrovka
# Processing record 388 | jieshi
# Processing record 389 | poum
# Processing record 390 | phan rang
# City not found. Skipping...
# Processing record 391 | mahanoro
# Processing record 392 | robat karim
# Processing record 393 | davila
# Processing record 394 | innisfail
# Processing record 395 | bilma
# Processing record 396 | sao geraldo do araguaia
# Processing record 397 | kibaya
# Processing record 398 | flin flon
# Processing record 399 | mlonggo
# Processing record 400 | sabha
# Processing record 401 | kandi
# Processing record 402 | calvinia
# Processing record 403 | bismarck
# Processing record 404 | arraial do cabo
# Processing record 405 | haldibari
# Processing record 406 | san patricio
# Processing record 407 | maragogi
# Processing record 408 | ocala
# Processing record 409 | saint combs
# City not found. Skipping...
# Processing record 410 | hovd
# Processing record 411 | codrington
# Processing record 412 | huarmey
# Processing record 413 | magadan
# Processing record 414 | spas-demensk
# Processing record 415 | harper
# Processing record 416 | great falls
# Processing record 417 | guiglo
# Processing record 418 | arlit
# Processing record 419 | andros town
# Processing record 420 | puerto colombia
# Processing record 421 | kutum
# Processing record 422 | pemba
# Processing record 423 | tomatlan
# Processing record 424 | pochutla
# Processing record 425 | gobabis
# Processing record 426 | tauranga
# Processing record 427 | boca do acre
# Processing record 428 | amiens
# Processing record 429 | san angelo
# Processing record 430 | vila velha
# Processing record 431 | thompson
# Processing record 432 | grindavik
# Processing record 433 | perth
# Processing record 434 | bratsk
# Processing record 435 | boueni
# Processing record 436 | havelock
# Processing record 437 | barawe
# City not found. Skipping...
# Processing record 438 | moerai
# Processing record 439 | luanda
# Processing record 440 | baherden
# Processing record 441 | fernie
# Processing record 442 | kruisfontein
# Processing record 443 | astana
# Processing record 444 | ossora
# Processing record 445 | beloha
# Processing record 446 | siddipet
# Processing record 447 | sabang
# Processing record 448 | launceston
# Processing record 449 | boyolangu
# Processing record 450 | amuntai
# Processing record 451 | lorengau
# Processing record 452 | lagunillas
# Processing record 453 | wewak
# Processing record 454 | cartagena del chaira
# Processing record 455 | rocha
# Processing record 456 | zatoka
# Processing record 457 | ishigaki
# Processing record 458 | katsuura
# Processing record 459 | tumannyy
# City not found. Skipping...
# Processing record 460 | uchkent
# Processing record 461 | coos bay
# Processing record 462 | presidencia roque saenz pena
# Processing record 463 | payo
# Processing record 464 | quelimane
# Processing record 465 | balykshi
# City not found. Skipping...
# Processing record 466 | bang saphan
# Processing record 467 | kabalo
# Processing record 468 | mbanza-ngungu
# Processing record 469 | rosario
# Processing record 470 | saint-jean-port-joli
# City not found. Skipping...
# Processing record 471 | skagastrond
# City not found. Skipping...
# Processing record 472 | saint-francois
# Processing record 473 | pietarsaari
# City not found. Skipping...
# Processing record 474 | urusha
# Processing record 475 | bryan
# Processing record 476 | huangchuan
# Processing record 477 | olavarria
# Processing record 478 | lake havasu city
# Processing record 479 | lyaskelya
# Processing record 480 | beringovskiy
# Processing record 481 | saint-georges
# Processing record 482 | andevoranto
# City not found. Skipping...
# Processing record 483 | dolbeau
# City not found. Skipping...
# Processing record 484 | aripuana
# Processing record 485 | sisimiut
# Processing record 486 | halifax
# Processing record 487 | asyut
# Processing record 488 | caronport
# Processing record 489 | kihei
# Processing record 490 | nacala
# Processing record 491 | portobelo
# Processing record 492 | san carlos de bariloche
# Processing record 493 | holbeach
# Processing record 494 | marcona
# City not found. Skipping...
# Processing record 495 | pozo colorado
# Processing record 496 | sentyabrskiy
# City not found. Skipping...
# Processing record 497 | copiapo
# Processing record 498 | sokoni
# Processing record 499 | rojhan
# Processing record 500 | port blair
# Processing record 501 | babanusah
# City not found. Skipping...
# Processing record 502 | bengkalis
# City not found. Skipping...
# Processing record 503 | beian
# Processing record 504 | vallenar
# Processing record 505 | necochea
# Processing record 506 | lima
# Processing record 507 | lyuban
# Processing record 508 | queanbeyan
# Processing record 509 | santa isabel do rio negro
# Processing record 510 | morondava
# Processing record 511 | hvammstangi
# City not found. Skipping...
# Processing record 512 | saint-jean-de-la-ruelle
# Processing record 513 | cleveland
# Processing record 514 | ust-maya
# Processing record 515 | olafsvik
# City not found. Skipping...
# Processing record 516 | ostersund
# Processing record 517 | senigallia
# Processing record 518 | sobolevo
# Processing record 519 | bayir
# Processing record 520 | cusuna
# Processing record 521 | altamont
# Processing record 522 | motril
# Processing record 523 | zhuhai
# Processing record 524 | mareeba
# Processing record 525 | otane
# Processing record 526 | borogontsy
# Processing record 527 | cilegon
# Processing record 528 | terney
# Processing record 529 | am timan
# Processing record 530 | okhotsk
# Processing record 531 | erenhot
# Processing record 532 | saint-pierre
# Processing record 533 | puerto penasco
# Processing record 534 | pontian kecil
# Processing record 535 | tamworth
# Processing record 536 | bellingham
# Processing record 537 | utiroa
# City not found. Skipping...
# Processing record 538 | attawapiskat
# City not found. Skipping...
# Processing record 539 | chagda
# City not found. Skipping...
# Processing record 540 | balkhash
# Processing record 541 | wokha
# Processing record 542 | bonfim
# Processing record 543 | gao
# Processing record 544 | llangefni
# Processing record 545 | staryy nadym
# Processing record 546 | constantine
# Processing record 547 | jujuy
# City not found. Skipping...
# Processing record 548 | gulaothi
# Processing record 549 | ruangwa
# Processing record 550 | tekeli
# Processing record 551 | nemuro
# Processing record 552 | dakar
# Processing record 553 | tura
# Processing record 554 | bouna
# Processing record 555 | alice springs
# Processing record 556 | roebourne
# Processing record 557 | shahreza
# Processing record 558 | aktau
# Processing record 559 | gornyy
# Processing record 560 | antigonish
# Processing record 561 | bengkulu
# City not found. Skipping...
# Processing record 562 | premia de mar
# Processing record 563 | freeport
# Processing record 564 | mangai
# Processing record 565 | singkang
# Processing record 566 | gravdal
# Processing record 567 | westport
# Processing record 568 | orotukan
# Processing record 569 | adrar
# Processing record 570 | bairiki
# City not found. Skipping...
# Processing record 571 | mumford
# Processing record 572 | bedele
# Processing record 573 | jizan
# Processing record 574 | nandurbar
# Processing record 575 | kandrian
# Processing record 576 | te anau
# Processing record 577 | ejido
# Processing record 578 | yuyao
# Processing record 579 | ukiah
# Processing record 580 | pauini
# Processing record 581 | sulangan
# Processing record 582 | kella
# Processing record 583 | redcar
# Processing record 584 | stoyba
# City not found. Skipping...
# Processing record 585 | uptar
# Processing record 586 | iguai
# Processing record 587 | recreio
# Processing record 588 | claremore
# Processing record 589 | snyder
# Processing record 590 | la ronge
# Processing record 591 | maghama
# City not found. Skipping...
# Processing record 592 | pamplona
# Processing record 593 | hunza
# City not found. Skipping...
# Processing record 594 | anchorage
# Processing record 595 | atambua
# Processing record 596 | atbasar
# Processing record 597 | kununurra
# Processing record 598 | rodeo
# Processing record 599 | huambo
# Processing record 600 | cabo san lucas
# Processing record 601 | ngukurr
# City not found. Skipping...
# Processing record 602 | ambulu
# Processing record 603 | rincon
# Processing record 604 | inta
# Processing record 605 | nurota
# Processing record 606 | taoudenni
# Processing record 607 | podgornoye
# Processing record 608 | fairmont
# Processing record 609 | wamba
# Processing record 610 | gimli
# Processing record 611 | puri
# Processing record 612 | marsh harbour
# Processing record 613 | san quintin
# Processing record 614 | iwanai
# Processing record 615 | swan hill
# Processing record 616 | puerto padre
# Processing record 617 | bemidji
# Processing record 618 | sinop
# Processing record 619 | buraydah
# Processing record 620 | boulder city
# Processing record 621 | dubrovytsya
# Processing record 622 | papillion
# Processing record 623 | paamiut
# Processing record 624 | necocli
# Processing record 625 | palmas de monte alto
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
goodweather.to_csv(output_data_file)

# Display counts of each column
goodweather.count()
# Out:
# City          564
# Cloudiness    564
# Country       564
# Date          564
# Humidity      564
# Lat           564
# Lng           564
# Max Temp      564
# Wind Speed    564
# dtype: int64

# %%
#Display the final dataframe
goodweather.head()
# Out:
#         City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0  Mount Isa         75      AU  1575155600       44 -20.73  139.49     78.8
# 1  Namatanai         25      PG  1575155600       66  -3.66  152.44    84.16
# 2   Cherskiy        100      RU  1575155600       91  68.75   161.3    -3.53
# 3    Mataura        100      NZ  1575155314       86 -46.19  168.86       59
# 4   Hermanus         84      ZA  1575155600       85 -34.42   19.24    62.01
#
#   Wind Speed
# 0      11.41
# 1       2.82
# 2      16.89
# 3          3
# 4      16.22

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plot a scatter plot of latitude vs temperature with formatting
plt.scatter(goodweather["Lat"], goodweather["Max Temp"], color="lightblue",
edgecolors = "k", s = 50)

# Plot title and axis labels as well as the grid
plt.title(f"City Latitude vs. Max Temperature (11/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# Save the figure to the output folder
plt.savefig("output_data/latVStemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plot a scatter plot of latitude vs humidity with formatting
plt.scatter(goodweather["Lat"], goodweather["Humidity"],color="lightblue",
edgecolors = "k", s = 50)

# Plot title and axis labels as well as the grid
plt.title("City Latitude vs. Humidity (11/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure to the output folder
plt.savefig("output_data/latVShum.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plot a scatter plot of latitude vs cloudiness with formatting
plt.scatter(goodweather["Lat"], goodweather["Cloudiness"],color="lightblue",
edgecolors = "k", s = 50)

# Plot title and axis labels as well as the grid
plt.title("City Latitude vs. Cloudiness (11/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure to the output folder
plt.savefig("output_data/latVScloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plot a scatter plot of latitude vs wind speed with formatting
plt.scatter(goodweather["Lat"], goodweather["Wind Speed"],color="lightblue",
edgecolors = "k", s = 50)

# Plot title and axis labels as well as the grid
plt.title("City Latitude vs. Wind Speed (11/30/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

plt.savefig("output_data/latVSwind.png")
